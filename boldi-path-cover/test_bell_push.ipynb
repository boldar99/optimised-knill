# %%
from bell_push import *
import pyzx as zx

h1 = [0, 4, 6]
cnots = [
    (0, 1), (4, 5), (6, 3), (6, 5), (4, 2), (0, 3), (4, 1), (3, 2),
]
c = Circuit.from_list(7, h1, cnots)
new_c = c.copy_with_bell_states()
print(new_c.ops)
print(new_c.qubits)
zx.draw(new_c.to_pyzx_circuit())
# Out:
# [BellState(i=3, j=6), BellState(i=5, j=4), BellState(i=1, j=0), ZState(i=2), CNOT(i=6, j=5), CNOT(i=4, j=2), CNOT(i=0, j=3), CNOT(i=4, j=1), CNOT(i=3, j=2)]
# [deque([(BellState(i=1, j=0), 2), (CNOT(i=0, j=3), 6)]), deque([(BellState(i=1, j=0), 2), (CNOT(i=4, j=1), 7)]), deque([(ZState(i=2), 3), (CNOT(i=4, j=2), 5), (CNOT(i=3, j=2), 8)]), deque([(BellState(i=3, j=6), 0), (CNOT(i=0, j=3), 6), (CNOT(i=3, j=2), 8)]), deque([(BellState(i=5, j=4), 1), (CNOT(i=4, j=2), 5), (CNOT(i=4, j=1), 7)]), deque([(BellState(i=5, j=4), 1), (CNOT(i=6, j=5), 4)]), deque([(BellState(i=3, j=6), 0), (CNOT(i=6, j=5), 4)])]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 12
#      10 print(new_c.ops)
#      11 print(new_c.qubits)
# ---> 12 zx.draw(new_c.to_pyzx_circuit())
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/drawing.py:67, in draw(g, labels, **kwargs)
#      65 else: # in notebook
#      66     if settings.drawing_backend == "d3":
# ---> 67         return draw_d3(g, labels, **kwargs)
#      68     elif settings.drawing_backend == "matplotlib":
#      69         return draw_matplotlib(g, labels, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/drawing.py:388, in draw_d3(g, labels, scale, auto_hbox, show_scalar, vdata, pauli_web, auto_layout)
#     385     auto_hbox = settings.drawing_auto_hbox
#     387 if isinstance(g, Circuit):
# --> 388     g = g.to_graph(zh=True)
#     390 # tracking global sequence can cause clashes if you restart the kernel without clearing ouput, so
#     391 # use an 8-digit random alphanum instead.
#     392 graph_id = ''.join(random_graphid.choice(string.ascii_letters + string.digits) for _ in range(8))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/circuit/__init__.py:268, in Circuit.to_graph(self, zh, compress_rows, backend)
#     263 """Turns the circuit into a ZX-Graph.
#     264 If ``compress_rows`` is set, it tries to put single qubit gates on different qubits,
#     265 on the same row."""
#     266 from .graphparser import circuit_to_graph
# --> 268 return circuit_to_graph(self if zh else self.to_basic_gates(),
#     269     compress_rows, backend)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/circuit/graphparser.py:145, in circuit_to_graph(c, compress_rows, backend)
#     143     q_mapper.set_all_rows_to_max()
#     144     c_mapper.set_all_rows_to_max()
# --> 145 gate.to_graph(g, q_mapper, c_mapper)
#     146 if not compress_rows: # or not isinstance(gate, (ZPhase, XPhase, HAD)):
#     147     q_mapper.set_max_row(max(q_mapper.max_row(), c_mapper.max_row()))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/circuit/gates.py:589, in CNOT.to_graph(self, g, q_mapper, _c_mapper)
#     587 def to_graph(self, g, q_mapper, _c_mapper):
#     588     [top, bot] = sorted([self.target, self.control])
# --> 589     r = max(q_mapper.next_row(r_) for r_ in range(top, bot + 1))
#     590     t = self.graph_add_node(g, q_mapper, VertexType.X, self.target, r)
#     591     c = self.graph_add_node(g, q_mapper, VertexType.Z, self.control, r)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/circuit/gates.py:589, in <genexpr>(.0)
#     587 def to_graph(self, g, q_mapper, _c_mapper):
#     588     [top, bot] = sorted([self.target, self.control])
# --> 589     r = max(q_mapper.next_row(r_) for r_ in range(top, bot + 1))
#     590     t = self.graph_add_node(g, q_mapper, VertexType.X, self.target, r)
#     591     c = self.graph_add_node(g, q_mapper, VertexType.Z, self.control, r)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/zxlive/lib/python3.12/site-packages/pyzx/circuit/gates.py:73, in TargetMapper.next_row(self, l)
#      69 def next_row(self, l: int) -> int:
#      70     """
#      71     Returns the next free row in the label's qubit.
#      72     """
# ---> 73     return self._rows[l]
#
# KeyError: 4

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 c._bell_states()
#
# File ~/PycharmProjects/FT-circuit-synthesis-ZX/boldi-path-cover/bell_push.py:102, in Circuit._bell_states(self)
#     100 qubit = qubits.pop()
#     101 queue = self.qubits[qubit]
# --> 102 a, b = queue[0], queue[1]
#     103 is_bell = False
#     104 if isinstance(a, ZState) and isinstance(b, CNOT):
#
# IndexError: deque index out of range
